# %%
# ── Mount Google Drive ─────────────────────────────────────────────────────────
# Run this cell first; authorize access in the popup that appears.
# After mounting, the dataset will be accessible under /content/drive/MyDrive/
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # EchoCare-CLIP Training Notebook
#
# This notebook trains a **CLIP-style contrastive model** that aligns echocardiography images (encoded by the pretrained **EchoCare SwinTransformer**) with clinical text descriptions (encoded by the **CLIP text encoder**).
#
# ## Architecture overview
# ```
# Image (B, 3, 256, 256)
#     → EchoCare SwinTransformer    → multi-scale features
#     → Global Average Pool (GAP)   → (B, 2048)
#     → MLP projection head         → (B, projection_dim)
#     → L2 normalize                → image_emb (B, projection_dim)
#
# Text (list of B strings)
#     → CLIP tokenizer              → (B, 77) token ids
#     → CLIP text encoder           → (B, 512)
#     → MLP projection head         → (B, projection_dim)
#     → L2 normalize                → text_emb (B, projection_dim)
#
# Loss: InfoNCE (symmetric cross-entropy on B×B cosine similarity matrix)
# ```
#
# ## Design choices
# - **Image encoder**: EchoCare SwinTransformer (`feature_size=128, depths=[2,2,18,2]`) pretrained with self-supervised MAE on echo data. We use its deepest feature map and apply GAP.
# - **Text encoder**: `openai/clip-vit-base-patch32` text tower (~63 M params). Chosen because (a) it is purpose-built for image–text alignment, (b) it is compact relative to larger language models, and (c) its embedding space is already semantically rich. We freeze its backbone and only train a projection head.
# - **Shared space**: `projection_dim=256`. Both modalities are L2-normalized before computing cosine similarity.
# - **Temperature**: Learnable `log_temperature`, initialized at `log(0.07)` following the original CLIP paper.

# %% [markdown]
# ## Step 0 — Install dependencies

# %%
# Install required packages.
# - monai:         provides the SwinTransformer used by EchoCare
# - transformers:  provides CLIPTextModel and CLIPTokenizer
# - einops:        needed internally by MONAI's SwinTransformer
# - matplotlib:    loss curves and benchmark plots
# - scikit-learn:  confusion matrix, t-SNE
# !pip install monai torch torchvision transformers einops matplotlib scikit-learn --quiet

# %% [markdown]
# ## Step 1 — Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

from torch.utils.data import Dataset, DataLoader

# MONAI SwinTransformer — the backbone used by EchoCare
from monai.networks.nets.swin_unetr import SwinTransformer

# Hugging Face CLIP text tower and tokenizer
from transformers import CLIPTokenizer, CLIPTextModel

print(f"PyTorch version : {torch.__version__}")
print(f"CUDA available  : {torch.cuda.is_available()}")
# Out:
# <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# PyTorch version : 2.10.0+cu128
# CUDA available  : True

# %% [markdown]
# ## Step 2 — Configuration
#
# All hyperparameters and paths live in a single `config` dict for easy modification.

# %%
# ── Configuration ──────────────────────────────────────────────────────────────
config = {
    # ── EchoCare image encoder ──────────────────────────────────────────────
    "feature_size"         : 128,          # SwinTransformer base channel dim
    "in_channels"          : 3,            # RGB images
    "image_size"           : 256,          # H = W of input images
    "image_embed_dim"      : 2048,         # deepest Swin stage output channels
    "pretrained_checkpoint": "echocare_encoder.pth",

    # ── Text encoder ────────────────────────────────────────────────────────
    "clip_model_name"      : "openai/clip-vit-base-patch32",
    "text_embed_dim"       : 512,          # CLIP text encoder hidden size
    "max_seq_len"          : 77,           # CLIP tokenizer max length

    # ── Shared latent space ─────────────────────────────────────────────────
    "projection_dim"       : 256,          # dim after projection heads

    # ── Dataset ─────────────────────────────────────────────────────────────
    # Path to the dataset root in Google Drive.
    # Structure: dataset_root / {train,validation,test} / {covid,healthy,other} / *.png
    "dataset_root"         : "/content/drive/MyDrive/BMI702 Project/A Dataset of Lung Ultrasound Images for Automated/dataset",
    "num_workers"          : 2,
    # ImageNet-style normalisation (standard starting point for SwinV2 on RGB data)
    "img_mean"             : [0.485, 0.456, 0.406],
    "img_std"              : [0.229, 0.224, 0.225],

    # ── Training ────────────────────────────────────────────────────────────
    "batch_size"           : 8,
    "num_epochs"           : 20,
    "lr"                   : 1e-5,
    "weight_decay"         : 1e-4,
    "init_temperature"     : 0.07,         # CLIP default starting temperature
}

print("Configuration loaded:")
for k, v in config.items():
    print(f"  {k:25s}: {v}")
# Out:
# Configuration loaded:
#   feature_size             : 128
#   in_channels              : 3
#   image_size               : 256
#   image_embed_dim          : 2048
#   pretrained_checkpoint    : echocare_encoder.pth
#   clip_model_name          : openai/clip-vit-base-patch32
#   text_embed_dim           : 512
#   max_seq_len              : 77
#   projection_dim           : 256
#   dataset_root             : /content/drive/MyDrive/BMI702 Project/A Dataset of Lung Ultrasound Images for Automated/dataset
#   num_workers              : 2
#   img_mean                 : [0.485, 0.456, 0.406]
#   img_std                  : [0.229, 0.224, 0.225]
#   batch_size               : 8
#   num_epochs               : 20
#   lr                       : 1e-05
#   weight_decay             : 0.0001
#   init_temperature         : 0.07

# %% [markdown]
# ## Step 3 — Lung Ultrasound Dataset and DataLoaders
#
# Loads real PNG images from Google Drive. Folder structure:
# ```
# dataset_root/
# ├── train/          ├── validation/      └── test/
# │   ├── covid/      │   ├── covid/           │   ├── covid/
# │   ├── healthy/    │   ├── healthy/         │   ├── healthy/
# │   └── other/      │   └── other/           │   └── other/
# ```
#
# Each label folder contains `.png` lung ultrasound frames. Labels are mapped to clinical text descriptions:
#
# | Label | Clinical Description |
# |-------|----------------------|
# | **covid** | "Lung ultrasound showing COVID-19 pneumonia with bilateral B-lines and consolidation." |
# | **healthy** | "Normal lung ultrasound with A-line pattern and no pathological findings." |
# | **other** | "Lung ultrasound showing abnormal findings consistent with non-COVID pulmonary pathology." |
#
# Images are resized to 256×256 and normalised with ImageNet statistics. Train split uses random augmentation (resize → random crop → horizontal flip); val/test use deterministic centre crop.

# %%
import os
from pathlib import Path
from PIL import Image
import torchvision.transforms as T

# ── Label-to-text mapping ──────────────────────────────────────────────────────
# Maps folder names (class labels) to structured clinical descriptions.
# These are encoded by the CLIP text encoder to form class prototypes at eval time.
LABEL_TO_TEXT = {
    "covid":   "Lung ultrasound showing COVID-19 pneumonia with bilateral B-lines and consolidation.",
    "healthy": "Normal lung ultrasound with A-line pattern and no pathological findings.",
    "other":   "Lung ultrasound showing abnormal findings consistent with non-COVID pulmonary pathology.",
}

LABEL_NAMES = ["covid", "healthy", "other"]  # canonical order for confusion matrix axes


class LungUltrasoundDataset(Dataset):
    """
    Lung ultrasound PNG dataset loaded from Google Drive.

    Folder structure:
      root_dir / split / label / *.png
      e.g. .../dataset/train/covid/frame001.png

    Each sample:
      image : torch.Tensor  shape (3, 256, 256), float32, normalised
      text  : str           clinical description string for the label
      label : str           folder name — "covid", "healthy", or "other"

    DataLoader collation:
      images : (B, 3, 256, 256)
      texts  : list[str] of len B  — tokenised later in the training loop
      labels : list[str] of len B  — used for classification evaluation
    """

    def __init__(
        self,
        root_dir    : str,
        split       : str,          # "train", "validation", or "test"
        transform,
        label_names : list = LABEL_NAMES,
    ):
        self.transform   = transform
        self.label_names = label_names
        self.samples : list[tuple[str, str]] = []  # (image_path, label)

        split_dir = Path(root_dir) / split
        if not split_dir.exists():
            raise FileNotFoundError(f"Split directory not found: {split_dir}")

        for label in label_names:
            label_dir = split_dir / label
            if not label_dir.exists():
                print(f"  [WARNING] Missing class folder: {label_dir}")
                continue
            png_files = sorted(label_dir.glob("*.png"))
            self.samples.extend((str(p), label) for p in png_files)

        if len(self.samples) == 0:
            raise RuntimeError(f"No PNG images found under {split_dir}")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        # Load and convert to RGB (handles grayscale / RGBA PNGs transparently)
        image = Image.open(img_path).convert("RGB")
        image = self.transform(image)      # → (3, 256, 256) normalised float tensor
        text  = LABEL_TO_TEXT[label]
        return image, text, label


# ── Transforms ─────────────────────────────────────────────────────────────────
_mean = config["img_mean"]
_std  = config["img_std"]

train_transform = T.Compose([
    T.Resize(288),                              # upscale slightly before random crop
    T.RandomCrop(config["image_size"]),         # random 256×256 crop
    T.RandomHorizontalFlip(),
    T.ToTensor(),                               # → float32 in [0, 1]
    T.Normalize(mean=_mean, std=_std),
])

eval_transform = T.Compose([
    T.Resize(config["image_size"]),             # resize shorter side to 256
    T.CenterCrop(config["image_size"]),         # deterministic 256×256 crop
    T.ToTensor(),
    T.Normalize(mean=_mean, std=_std),
])

# ── Build datasets ─────────────────────────────────────────────────────────────
train_dataset = LungUltrasoundDataset(config["dataset_root"], "train",      train_transform)
val_dataset   = LungUltrasoundDataset(config["dataset_root"], "validation", eval_transform)
test_dataset  = LungUltrasoundDataset(config["dataset_root"], "test",       eval_transform)

# ── Build dataloaders ──────────────────────────────────────────────────────────
train_loader = DataLoader(
    train_dataset, batch_size=config["batch_size"], shuffle=True,
    num_workers=config["num_workers"], pin_memory=True,
)
val_loader = DataLoader(
    val_dataset, batch_size=config["batch_size"], shuffle=False,
    num_workers=config["num_workers"], pin_memory=True,
)
test_loader = DataLoader(
    test_dataset, batch_size=config["batch_size"], shuffle=False,
    num_workers=config["num_workers"], pin_memory=True,
)

# ── Dataset statistics ─────────────────────────────────────────────────────────
print("Dataset statistics:")
for split_name, ds in [("train", train_dataset), ("val", val_dataset), ("test", test_dataset)]:
    counts = {lbl: 0 for lbl in LABEL_NAMES}
    for _, lbl in ds.samples:
        counts[lbl] += 1
    total      = sum(counts.values())
    counts_str = "  ".join(f"{lbl}: {n}" for lbl, n in counts.items())
    print(f"  {split_name:12s}: {total:5d} total  |  {counts_str}")

# ── Sanity check one batch ─────────────────────────────────────────────────────
sample_images, sample_texts, sample_labels = next(iter(train_loader))
print(f"\nBatch image shape : {sample_images.shape}")        # Expected: (B, 3, 256, 256)
print(f"Batch texts (1st) : {sample_texts[0]}")
print(f"Batch labels      : {list(sample_labels)}")
print(f"Image value range : [{sample_images.min():.3f}, {sample_images.max():.3f}]")
# Out:
# Dataset statistics:
#   train       :   468 total  |  covid: 170  healthy: 194  other: 104
#   val         :   136 total  |  covid: 42  healthy: 53  other: 41
#   test        :    84 total  |  covid: 7  healthy: 55  other: 22
#
# Batch image shape : torch.Size([8, 3, 256, 256])
# Batch texts (1st) : Lung ultrasound showing abnormal findings consistent with non-COVID pulmonary pathology.
# Batch labels      : ['other', 'other', 'covid', 'other', 'healthy', 'other', 'healthy', 'healthy']
# Image value range : [-2.118, 2.640]

# %% [markdown]
# ## Step 4 — EchoCare Image Encoder
#
# Wraps the pretrained SwinTransformer with a two-layer MLP projection head.
#
# **SwinTransformer output stages** (with `feature_size=128`, input `256×256`):
#
# | Stage | Channels | Spatial size |
# |-------|----------|--------------|
# | 0     | 128      | 128×128      |
# | 1     | 256      | 64×64        |
# | 2     | 512      | 32×32        |
# | 3     | 1024     | 16×16        |
# | 4     | **2048** | **8×8**      |
#
# We use **stage 4** (deepest, most semantic) and apply **Global Average Pool** to get a `(B, 2048)` vector, then project to `(B, projection_dim)`.

# %%
class EchoCareImageEncoder(nn.Module):
    """
    EchoCare SwinTransformer backbone + MLP projection head.

    Data shapes through the forward pass
    -------------------------------------
    Input image          : (B, 3, 256, 256)
    Swin stage 0         : (B, 128,  128, 128)
    Swin stage 1         : (B, 256,   64,  64)
    Swin stage 2         : (B, 512,   32,  32)
    Swin stage 3         : (B, 1024,  16,  16)
    Swin stage 4 (deep)  : (B, 2048,   8,   8)
    After GAP            : (B, 2048)
    After MLP projection : (B, projection_dim)
    After L2 norm        : (B, projection_dim)  ← output
    """

    def __init__(
        self,
        feature_size   : int  = 128,
        in_channels    : int  = 3,
        projection_dim : int  = 256,
        use_checkpoint : bool = True,
        freeze_encoder : bool = False,
    ):
        super().__init__()

        # ── EchoCare SwinTransformer backbone ─────────────────────────────
        # Exact same config as echocare_test.ipynb to ensure weight compatibility.
        # spatial_dims=2  →  2-D (frame-level, not volumetric)
        # use_v2=True     →  SwinV2 improvements (log-spaced relative position bias)
        self.encoder = SwinTransformer(
            in_chans      = in_channels,
            embed_dim     = feature_size,        # 128
            window_size   = [8, 8],
            patch_size    = [2, 2],
            depths        = [2, 2, 18, 2],
            num_heads     = [4, 8, 16, 32],
            mlp_ratio     = 4.0,
            qkv_bias      = True,
            use_checkpoint= use_checkpoint,
            spatial_dims  = 2,
            use_v2        = True,
        )

        # ── Compute deepest feature dim ───────────────────────────────────
        # Each Swin stage doubles channel count; 4 downsampling stages:
        # 128 → 256 → 512 → 1024 → 2048
        num_downsample   = 4          # len(depths) - 1, since last stage is bottleneck
        encoder_out_dim  = feature_size * (2 ** num_downsample)  # 128 * 16 = 2048

        # ── Projection head ───────────────────────────────────────────────
        # Two-layer MLP with ReLU, following MoCo v3 / CLIP convention.
        # Maps 2048-dim image embedding → projection_dim for alignment.
        self.projection = nn.Sequential(
            nn.Linear(encoder_out_dim, encoder_out_dim),
            nn.ReLU(),
            nn.Linear(encoder_out_dim, projection_dim),
        )

        # ── Optional backbone freeze ──────────────────────────────────────
        # Freeze if the pretrained backbone is strong and we only want to
        # learn the projection. Set to False to allow full fine-tuning.
        if freeze_encoder:
            for param in self.encoder.parameters():
                param.requires_grad = False

    def load_pretrained(self, checkpoint_path: str, device: str = "cpu"):
        """
        Load EchoCare self-supervised pretrained weights.

        The checkpoint stores a flat state_dict of SwinTransformer weights
        plus an extra 'mask_token' key from MAE pretraining that does not
        exist in the plain SwinTransformer, so we pop it before loading.
        """
        state_dict = torch.load(checkpoint_path, map_location=device)
        state_dict.pop("mask_token", None)   # MAE artefact — not in SwinTransformer
        self.encoder.load_state_dict(state_dict, strict=True)
        print(f"Loaded EchoCare pretrained weights from '{checkpoint_path}'")

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        x : (B, 3, 256, 256)  — normalised echo frames
        returns: (B, projection_dim) L2-normalised image embeddings
        """
        # Multi-scale feature extraction
        # feats[k] shape: see docstring table above
        feats = self.encoder(x)

        # Use the deepest (most semantic) feature map
        deep = feats[-1]              # (B, 2048, 8, 8)

        # Global Average Pooling over spatial dimensions
        emb  = deep.mean(dim=(2, 3)) # (B, 2048)

        # Project to shared latent space
        emb  = self.projection(emb)  # (B, projection_dim)

        # L2 normalise so dot product == cosine similarity
        emb  = F.normalize(emb, dim=-1)  # (B, projection_dim)

        return emb

# %% [markdown]
# ## Step 5 — Text Encoder
#
# **Choice: CLIP text encoder (`openai/clip-vit-base-patch32`)**
#
# Rationale for this choice over alternatives:
#
# | Option | Pros | Cons |
# |--------|------|------|
# | **CLIP text encoder** (chosen) | Purpose-built for image–text alignment; compact (~63 M); already meaningful token embeddings | Not domain-adapted to medical text |
# | GPT-2 | Flexible; widely supported | Causal LM, not ideal for embedding; needs pooling heuristic |
# | DistilBERT | Very small; fast | No pretraining on image–text pairs |
# | PubMedBERT | Medical domain | Larger; no prior image–text alignment |
#
# We **freeze** the CLIP text encoder backbone and only train its projection head. This prevents catastrophic forgetting of the pretrained text representations while the image encoder adapts.

# %%
class CLIPTextEncoder(nn.Module):
    """
    CLIP text tower + MLP projection head.

    Data shapes through the forward pass
    -------------------------------------
    Input token ids    : (B, 77)              — CLIP fixed max length
    Attention mask     : (B, 77)
    CLIP pooler output : (B, 512)             — [EOS] token embedding
    After MLP proj     : (B, projection_dim)
    After L2 norm      : (B, projection_dim)  ← output

    Note: CLIP uses the embedding at the position of the [EOS] token
    (highest-indexed non-padding token) as the sentence representation.
    `pooler_output` from CLIPTextModel returns exactly this.
    """

    def __init__(
        self,
        clip_model_name     : str  = "openai/clip-vit-base-patch32",
        projection_dim      : int  = 256,
        freeze_text_encoder : bool = True,
    ):
        super().__init__()

        # ── Pretrained CLIP text tower ────────────────────────────────────
        # CLIPTextModel is the text-only part of the full CLIP model.
        # hidden_size = 512 for clip-vit-base-patch32.
        self.text_encoder = CLIPTextModel.from_pretrained(clip_model_name)
        text_out_dim      = self.text_encoder.config.hidden_size  # 512

        # ── Freeze backbone (recommended starting point) ──────────────────
        # Only the projection head is updated during early training.
        # Unfreeze text_encoder if domain shift from general CLIP is large.
        if freeze_text_encoder:
            for param in self.text_encoder.parameters():
                param.requires_grad = False

        # ── Projection head ───────────────────────────────────────────────
        # Same two-layer MLP structure as the image encoder's projection head
        # for symmetry.
        self.projection = nn.Sequential(
            nn.Linear(text_out_dim, text_out_dim),
            nn.ReLU(),
            nn.Linear(text_out_dim, projection_dim),
        )

    def forward(
        self,
        input_ids     : torch.Tensor,
        attention_mask: torch.Tensor | None = None,
    ) -> torch.Tensor:
        """
        input_ids      : (B, 77)  LongTensor of token ids
        attention_mask : (B, 77)  1 for real tokens, 0 for padding
        returns        : (B, projection_dim) L2-normalised text embeddings
        """
        # CLIP text encoding
        # pooler_output: embedding of the [EOS] (end-of-sequence) token,
        # which aggregates the full sequence representation in CLIP.
        outputs  = self.text_encoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
        )
        text_emb = outputs.pooler_output   # (B, 512)

        # Project to shared latent space
        text_emb = self.projection(text_emb)  # (B, projection_dim)

        # L2 normalise
        text_emb = F.normalize(text_emb, dim=-1)  # (B, projection_dim)

        return text_emb

# %% [markdown]
# ## Step 6 — EchoCare-CLIP: Combined CLIP-style Model
#
# Combines both encoders and implements the **InfoNCE (symmetric cross-entropy) loss**:
#
# ```
# logits_per_image[i, j] = sim(image_i, text_j) / temperature
#                                              ↑ (B × B matrix)
# Diagonal = positive pairs (same study).
# Loss = 0.5 * (CE_rows + CE_cols),  labels = [0, 1, 2, ..., B-1]
# ```

# %%
class EchoCare_CLIP(nn.Module):
    """
    CLIP-style contrastive model:
      EchoCare image encoder  ↕  alignment  ↕  CLIP text encoder

    Training objective
    ------------------
    Given a batch of B matched (image, text) pairs:
      1. Compute image_emb: (B, projection_dim)  — L2 normalised
      2. Compute text_emb : (B, projection_dim)  — L2 normalised
      3. Similarity matrix: logits = image_emb @ text_emb.T / temperature
                            shape  : (B, B)
      4. InfoNCE (symmetric cross-entropy):
           loss = 0.5 * [CE(logits, labels) + CE(logits.T, labels)]
           where labels = [0, 1, ..., B-1]  (diagonal = positives)

    Temperature
    -----------
    Stored as log_temperature (log scale) for numerical stability.
    Actual temperature = exp(log_temperature), learnable parameter.
    Initialised to log(0.07) following the original CLIP paper.
    """

    def __init__(
        self,
        image_encoder   : EchoCareImageEncoder,
        text_encoder    : CLIPTextEncoder,
        init_temperature: float = 0.07,
    ):
        super().__init__()
        self.image_encoder  = image_encoder
        self.text_encoder   = text_encoder

        # Learnable temperature (log scale)
        self.log_temperature = nn.Parameter(
            torch.log(torch.tensor(init_temperature))
        )

    # ── Convenience encode methods for inference ───────────────────────────
    def encode_image(self, images: torch.Tensor) -> torch.Tensor:
        """images: (B, 3, 256, 256) → (B, projection_dim)"""
        return self.image_encoder(images)

    def encode_text(
        self,
        input_ids     : torch.Tensor,
        attention_mask: torch.Tensor | None = None,
    ) -> torch.Tensor:
        """input_ids: (B, 77) → (B, projection_dim)"""
        return self.text_encoder(input_ids, attention_mask)

    def forward(
        self,
        images        : torch.Tensor,
        input_ids     : torch.Tensor,
        attention_mask: torch.Tensor | None = None,
    ):
        """
        Full forward pass (training).

        Args
        ----
        images         : (B, 3, 256, 256)
        input_ids      : (B, 77)             token ids from CLIPTokenizer
        attention_mask : (B, 77)             padding mask

        Returns
        -------
        loss      : scalar  InfoNCE contrastive loss
        image_emb : (B, projection_dim)  L2-normalised image embeddings
        text_emb  : (B, projection_dim)  L2-normalised text embeddings
        """
        # Encode both modalities
        image_emb = self.encode_image(images)                       # (B, D)
        text_emb  = self.encode_text(input_ids, attention_mask)     # (B, D)

        # Current temperature (positive scalar)
        temperature = self.log_temperature.exp()   # scalar

        # Pairwise cosine similarity matrix, scaled by 1/temperature
        # Both embeddings are L2-normalised → dot product == cosine similarity
        logits_per_image = (image_emb @ text_emb.T) / temperature   # (B, B)
        logits_per_text  = logits_per_image.T                        # (B, B)

        # Ground-truth: sample i is paired with text i (diagonal)
        labels = torch.arange(image_emb.size(0), device=image_emb.device)  # (B,)

        # Symmetric InfoNCE loss
        loss_i2t = F.cross_entropy(logits_per_image, labels)
        loss_t2i = F.cross_entropy(logits_per_text,  labels)
        loss     = (loss_i2t + loss_t2i) / 2

        return loss, image_emb, text_emb

# %% [markdown]
# ## Step 7 — Initialise Models and Load Pretrained Weights

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# ── Image encoder ─────────────────────────────────────────────────────────────
# use_checkpoint=False: disable gradient checkpointing for the dummy run
#   (checkpointing trades compute for memory; enable it for large batches)
# freeze_encoder=False: allow full fine-tuning; set True if GPU memory is tight
image_encoder = EchoCareImageEncoder(
    feature_size   = config["feature_size"],
    in_channels    = config["in_channels"],
    projection_dim = config["projection_dim"],
    use_checkpoint = False,
    freeze_encoder = False,
)

# Load pretrained EchoCare weights.
# Expected checkpoint path: "echocare_encoder.pth"
# Falls back to random init if the file is not found (fine for code verification).
try:
    image_encoder.load_pretrained(
        config["pretrained_checkpoint"],
        device=str(device),
    )
except FileNotFoundError:
    print(f"[WARNING] Checkpoint not found at '{config['pretrained_checkpoint']}'.")
    print("[WARNING] Continuing with random initialisation for code verification.")

# ── Text encoder ──────────────────────────────────────────────────────────────
# freeze_text_encoder=True: CLIP backbone is frozen; only projection is trained.
# This is the recommended starting point to avoid destroying CLIP's alignment.
text_encoder = CLIPTextEncoder(
    clip_model_name     = config["clip_model_name"],
    projection_dim      = config["projection_dim"],
    freeze_text_encoder = True,
)

# ── Tokenizer (needed before training loop) ───────────────────────────────────
tokenizer = CLIPTokenizer.from_pretrained(config["clip_model_name"])

# ── Combined model ────────────────────────────────────────────────────────────
model = EchoCare_CLIP(
    image_encoder    = image_encoder,
    text_encoder     = text_encoder,
    init_temperature = config["init_temperature"],
).to(device)

# ── Parameter counts ──────────────────────────────────────────────────────────
total_params     = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nTotal parameters     : {total_params:,}")
print(f"Trainable parameters : {trainable_params:,}")
print(f"  (CLIP text encoder backbone is frozen → smaller effective model)")
# Out:
# Device: cuda
# [WARNING] Checkpoint not found at 'echocare_encoder.pth'.
# [WARNING] Continuing with random initialisation for code verification.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                                            | Status     |  |
# ---------------------------------------------------------------+------------+--+-
# vision_model.encoder.layers.{0...11}.self_attn.k_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.layer_norm2.bias          | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.v_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.out_proj.bias   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.k_proj.bias     | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc2.bias              | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.q_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.v_proj.bias     | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.layer_norm1.weight        | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.layer_norm2.weight        | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.q_proj.bias     | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc1.bias              | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc1.weight            | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc2.weight            | UNEXPECTED |  |
# vision_model.embeddings.patch_embedding.weight                 | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.layer_norm1.bias          | UNEXPECTED |  |
# vision_model.post_layernorm.weight                             | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.out_proj.weight | UNEXPECTED |  |
# vision_model.pre_layrnorm.weight                               | UNEXPECTED |  |
# vision_model.embeddings.class_embedding                        | UNEXPECTED |  |
# vision_model.embeddings.position_ids                           | UNEXPECTED |  |
# text_projection.weight                                         | UNEXPECTED |  |
# vision_model.pre_layrnorm.bias                                 | UNEXPECTED |  |
# logit_scale                                                    | UNEXPECTED |  |
# vision_model.post_layernorm.bias                               | UNEXPECTED |  |
# visual_projection.weight                                       | UNEXPECTED |  |
# text_model.embeddings.position_ids                             | UNEXPECTED |  |
# vision_model.embeddings.position_embedding.weight              | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Total parameters     : 188,502,521
# Trainable parameters : 125,336,569
#   (CLIP text encoder backbone is frozen → smaller effective model)

# %% [markdown]
# ## Step 8 — Text Tokenisation Helper

# %%
def tokenize_texts(
    texts      : list[str],
    tokenizer  : CLIPTokenizer,
    max_length : int = 77,
    device     : torch.device | str = "cpu",
) -> tuple[torch.Tensor, torch.Tensor]:
    """
    Tokenise a list of strings with the CLIP tokenizer.

    CLIP uses a fixed context window of 77 tokens (including [SOS] and [EOS]).
    Sequences shorter than 77 are right-padded; longer ones are truncated.

    Args
    ----
    texts      : list of B strings
    tokenizer  : CLIPTokenizer instance
    max_length : 77 (CLIP default)
    device     : target device

    Returns
    -------
    input_ids      : (B, 77)  LongTensor
    attention_mask : (B, 77)  LongTensor  (1 = real token, 0 = padding)
    """
    encoded = tokenizer(
        texts,
        padding   = "max_length",
        max_length = max_length,
        truncation = True,
        return_tensors = "pt",
    )
    return (
        encoded["input_ids"].to(device),
        encoded["attention_mask"].to(device),
    )


# ── Quick tokeniser sanity check ──────────────────────────────────────────────
test_texts = ["Normal cardiac function.", "Severe aortic stenosis."]
ids, mask  = tokenize_texts(test_texts, tokenizer, device=device)
print(f"input_ids shape      : {ids.shape}"     )  # Expected: (2, 77)
print(f"attention_mask shape : {mask.shape}"    )  # Expected: (2, 77)
print(f"Non-padding tokens   : {mask.sum(dim=1).tolist()}")  # token counts per string
# Out:
# input_ids shape      : torch.Size([2, 77])
# attention_mask shape : torch.Size([2, 77])
# Non-padding tokens   : [6, 8]

# %% [markdown]
# ## Step 9 — Training Loop

# %%
# ── Optimiser ─────────────────────────────────────────────────────────────────
# AdamW is standard for transformer fine-tuning.
# filter(requires_grad) skips the frozen CLIP text backbone.
optimizer = torch.optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr           = config["lr"],
    weight_decay = config["weight_decay"],
)

# Cosine annealing LR schedule — smooth decay over all training epochs.
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=config["num_epochs"]
)


def train_one_epoch(
    model     : EchoCare_CLIP,
    dataloader: DataLoader,
    optimizer : torch.optim.Optimizer,
    tokenizer : CLIPTokenizer,
    device    : torch.device,
    epoch     : int,
) -> float:
    """
    Run one full training epoch.

    Batch data flow
    ---------------
    images (B, 3, 256, 256)  →  image_emb  (B, projection_dim)
    texts  list[str] of B    →  text_emb   (B, projection_dim)
    loss: scalar symmetric InfoNCE

    Returns average loss over all batches.
    """
    model.train()
    total_loss = 0.0

    for batch_idx, (images, texts, _) in enumerate(dataloader):
        images = images.to(device)
        input_ids, attention_mask = tokenize_texts(texts, tokenizer, device=device)

        optimizer.zero_grad()
        loss, image_emb, text_emb = model(images, input_ids, attention_mask)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Print every 10 batches and at the last batch to avoid log spam
        if batch_idx % 10 == 0 or batch_idx == len(dataloader) - 1:
            print(
                f"  [Epoch {epoch+1}] Batch {batch_idx+1}/{len(dataloader)}"
                f" | Loss: {loss.item():.4f}"
                f" | Temp: {model.log_temperature.exp().item():.4f}"
            )

    return total_loss / len(dataloader)


@torch.no_grad()
def validate_one_epoch(
    model     : EchoCare_CLIP,
    dataloader: DataLoader,
    tokenizer : CLIPTokenizer,
    device    : torch.device,
) -> float:
    """Run validation pass; returns average InfoNCE loss (no gradients)."""
    model.eval()
    total_loss = 0.0
    for images, texts, _ in dataloader:
        images = images.to(device)
        input_ids, attention_mask = tokenize_texts(texts, tokenizer, device=device)
        loss, _, _ = model(images, input_ids, attention_mask)
        total_loss += loss.item()
    return total_loss / len(dataloader)


# ── Training loop ──────────────────────────────────────────────────────────────
train_losses : list[float] = []
val_losses   : list[float] = []
best_val_loss = float("inf")

print("Starting training...\n")
for epoch in range(config["num_epochs"]):
    avg_train = train_one_epoch(model, train_loader, optimizer, tokenizer, device, epoch)
    avg_val   = validate_one_epoch(model, val_loader, tokenizer, device)
    scheduler.step()

    train_losses.append(avg_train)
    val_losses.append(avg_val)

    lr_now = scheduler.get_last_lr()[0]
    print(
        f">>> Epoch {epoch+1:2d}/{config['num_epochs']}"
        f"  Train: {avg_train:.4f}  Val: {avg_val:.4f}  LR: {lr_now:.2e}\n"
    )

    # Checkpoint whenever validation loss improves
    if avg_val < best_val_loss:
        best_val_loss = avg_val
        torch.save(model.state_dict(), "echocare_clip_best.pth")
        print(f"  [Checkpoint] New best val loss: {best_val_loss:.4f} — saved to echocare_clip_best.pth\n")

print(f"Training complete. Best val loss: {best_val_loss:.4f}")
# Out:
# Starting training...
#
#   [Epoch 1] Batch 1/59 | Loss: 2.0784 | Temp: 0.0700
#   [Epoch 1] Batch 11/59 | Loss: 1.7745 | Temp: 0.0700
#   [Epoch 1] Batch 21/59 | Loss: 1.7188 | Temp: 0.0700
#   [Epoch 1] Batch 31/59 | Loss: 2.1925 | Temp: 0.0700
#   [Epoch 1] Batch 41/59 | Loss: 1.6470 | Temp: 0.0700
#   [Epoch 1] Batch 51/59 | Loss: 1.4272 | Temp: 0.0700
#   [Epoch 1] Batch 59/59 | Loss: 1.5705 | Temp: 0.0700
# >>> Epoch  1/20  Train: 1.7265  Val: 2.0972  LR: 9.94e-06
#
#   [Checkpoint] New best val loss: 2.0972 — saved to echocare_clip_best.pth
#
#   [Epoch 2] Batch 1/59 | Loss: 1.8656 | Temp: 0.0700
#   [Epoch 2] Batch 11/59 | Loss: 1.9155 | Temp: 0.0700
#   [Epoch 2] Batch 21/59 | Loss: 1.7173 | Temp: 0.0700
#   [Epoch 2] Batch 31/59 | Loss: 1.5315 | Temp: 0.0700
#   [Epoch 2] Batch 41/59 | Loss: 1.5754 | Temp: 0.0700
#   [Epoch 2] Batch 51/59 | Loss: 1.6124 | Temp: 0.0700
#   [Epoch 2] Batch 59/59 | Loss: 0.5181 | Temp: 0.0700
# >>> Epoch  2/20  Train: 1.6276  Val: 2.0918  LR: 9.76e-06
#
#   [Checkpoint] New best val loss: 2.0918 — saved to echocare_clip_best.pth
#
#   [Epoch 3] Batch 1/59 | Loss: 1.5487 | Temp: 0.0700
#   [Epoch 3] Batch 11/59 | Loss: 1.8771 | Temp: 0.0700
#   [Epoch 3] Batch 21/59 | Loss: 1.4046 | Temp: 0.0700
#   [Epoch 3] Batch 31/59 | Loss: 1.5483 | Temp: 0.0700
#   [Epoch 3] Batch 41/59 | Loss: 1.5073 | Temp: 0.0700
#   [Epoch 3] Batch 51/59 | Loss: 1.5287 | Temp: 0.0700
#   [Epoch 3] Batch 59/59 | Loss: 0.7956 | Temp: 0.0700
# >>> Epoch  3/20  Train: 1.5550  Val: 2.0867  LR: 9.46e-06
#
#   [Checkpoint] New best val loss: 2.0867 — saved to echocare_clip_best.pth
#
#   [Epoch 4] Batch 1/59 | Loss: 1.5394 | Temp: 0.0700
#   [Epoch 4] Batch 11/59 | Loss: 1.5148 | Temp: 0.0700
#   [Epoch 4] Batch 21/59 | Loss: 1.4013 | Temp: 0.0700
#   [Epoch 4] Batch 31/59 | Loss: 1.4942 | Temp: 0.0700
#   [Epoch 4] Batch 41/59 | Loss: 1.1231 | Temp: 0.0700
#   [Epoch 4] Batch 51/59 | Loss: 1.8252 | Temp: 0.0700
#   [Epoch 4] Batch 59/59 | Loss: 0.9074 | Temp: 0.0700
# >>> Epoch  4/20  Train: 1.5236  Val: 2.1163  LR: 9.05e-06
#
#   [Epoch 5] Batch 1/59 | Loss: 1.9460 | Temp: 0.0700
#   [Epoch 5] Batch 11/59 | Loss: 1.5597 | Temp: 0.0700
#   [Epoch 5] Batch 21/59 | Loss: 1.1171 | Temp: 0.0700
#   [Epoch 5] Batch 31/59 | Loss: 2.1892 | Temp: 0.0700
#   [Epoch 5] Batch 41/59 | Loss: 1.8321 | Temp: 0.0700
#   [Epoch 5] Batch 51/59 | Loss: 1.6392 | Temp: 0.0700
#   [Epoch 5] Batch 59/59 | Loss: 0.7305 | Temp: 0.0700
# >>> Epoch  5/20  Train: 1.5443  Val: 2.1013  LR: 8.54e-06
#
#   [Epoch 6] Batch 1/59 | Loss: 1.6203 | Temp: 0.0700
#   [Epoch 6] Batch 11/59 | Loss: 1.6263 | Temp: 0.0700
#   [Epoch 6] Batch 21/59 | Loss: 1.3171 | Temp: 0.0700
#   [Epoch 6] Batch 31/59 | Loss: 1.5367 | Temp: 0.0700
#   [Epoch 6] Batch 41/59 | Loss: 1.4293 | Temp: 0.0700
#   [Epoch 6] Batch 51/59 | Loss: 1.6386 | Temp: 0.0700
#   [Epoch 6] Batch 59/59 | Loss: 0.8604 | Temp: 0.0700
# >>> Epoch  6/20  Train: 1.5006  Val: 2.1125  LR: 7.94e-06
#
#   [Epoch 7] Batch 1/59 | Loss: 1.4166 | Temp: 0.0700
#   [Epoch 7] Batch 11/59 | Loss: 1.8627 | Temp: 0.0700
#   [Epoch 7] Batch 21/59 | Loss: 1.5493 | Temp: 0.0700
#   [Epoch 7] Batch 31/59 | Loss: 1.8471 | Temp: 0.0700
#   [Epoch 7] Batch 41/59 | Loss: 1.5513 | Temp: 0.0700
#   [Epoch 7] Batch 51/59 | Loss: 1.5018 | Temp: 0.0700
#   [Epoch 7] Batch 59/59 | Loss: 0.8487 | Temp: 0.0700
# >>> Epoch  7/20  Train: 1.4643  Val: 2.0942  LR: 7.27e-06
#
#   [Epoch 8] Batch 1/59 | Loss: 1.3096 | Temp: 0.0700
#   [Epoch 8] Batch 11/59 | Loss: 1.3495 | Temp: 0.0700
#   [Epoch 8] Batch 21/59 | Loss: 1.0948 | Temp: 0.0700
#   [Epoch 8] Batch 31/59 | Loss: 1.5161 | Temp: 0.0700
#   [Epoch 8] Batch 41/59 | Loss: 1.3522 | Temp: 0.0700
#   [Epoch 8] Batch 51/59 | Loss: 1.5307 | Temp: 0.0700
#   [Epoch 8] Batch 59/59 | Loss: 1.4073 | Temp: 0.0700
# >>> Epoch  8/20  Train: 1.4604  Val: 2.1236  LR: 6.55e-06
#
#   [Epoch 9] Batch 1/59 | Loss: 1.4849 | Temp: 0.0700
#   [Epoch 9] Batch 11/59 | Loss: 1.1954 | Temp: 0.0700
#   [Epoch 9] Batch 21/59 | Loss: 1.9104 | Temp: 0.0700
#   [Epoch 9] Batch 31/59 | Loss: 1.6895 | Temp: 0.0700
#   [Epoch 9] Batch 41/59 | Loss: 1.2375 | Temp: 0.0700
#   [Epoch 9] Batch 51/59 | Loss: 1.5435 | Temp: 0.0700
#   [Epoch 9] Batch 59/59 | Loss: 0.8477 | Temp: 0.0700
# >>> Epoch  9/20  Train: 1.4336  Val: 2.1295  LR: 5.78e-06
#
#   [Epoch 10] Batch 1/59 | Loss: 1.5679 | Temp: 0.0700
#   [Epoch 10] Batch 11/59 | Loss: 1.4051 | Temp: 0.0700
#   [Epoch 10] Batch 21/59 | Loss: 1.7338 | Temp: 0.0700
#   [Epoch 10] Batch 31/59 | Loss: 1.1436 | Temp: 0.0700
#   [Epoch 10] Batch 41/59 | Loss: 1.4831 | Temp: 0.0700
#   [Epoch 10] Batch 51/59 | Loss: 1.2101 | Temp: 0.0700
#   [Epoch 10] Batch 59/59 | Loss: 0.8312 | Temp: 0.0700
# >>> Epoch 10/20  Train: 1.3898  Val: 2.1698  LR: 5.00e-06
#
#   [Epoch 11] Batch 1/59 | Loss: 1.4735 | Temp: 0.0700
#   [Epoch 11] Batch 11/59 | Loss: 1.3667 | Temp: 0.0700
#   [Epoch 11] Batch 21/59 | Loss: 1.2959 | Temp: 0.0700
#   [Epoch 11] Batch 31/59 | Loss: 2.0112 | Temp: 0.0700
#   [Epoch 11] Batch 41/59 | Loss: 1.5693 | Temp: 0.0700
#   [Epoch 11] Batch 51/59 | Loss: 1.7232 | Temp: 0.0700
#   [Epoch 11] Batch 59/59 | Loss: 0.8934 | Temp: 0.0700
# >>> Epoch 11/20  Train: 1.3753  Val: 2.1753  LR: 4.22e-06
#
#   [Epoch 12] Batch 1/59 | Loss: 1.1237 | Temp: 0.0700
#   [Epoch 12] Batch 11/59 | Loss: 1.6294 | Temp: 0.0700
#   [Epoch 12] Batch 21/59 | Loss: 1.3322 | Temp: 0.0700
#   [Epoch 12] Batch 31/59 | Loss: 1.1977 | Temp: 0.0700
#   [Epoch 12] Batch 41/59 | Loss: 1.1567 | Temp: 0.0700
#   [Epoch 12] Batch 51/59 | Loss: 1.3194 | Temp: 0.0700
#   [Epoch 12] Batch 59/59 | Loss: 0.8329 | Temp: 0.0700
# >>> Epoch 12/20  Train: 1.3437  Val: 2.1246  LR: 3.45e-06
#
#   [Epoch 13] Batch 1/59 | Loss: 1.2985 | Temp: 0.0700
#   [Epoch 13] Batch 11/59 | Loss: 1.2170 | Temp: 0.0700
#   [Epoch 13] Batch 21/59 | Loss: 1.3578 | Temp: 0.0700
#   [Epoch 13] Batch 31/59 | Loss: 1.2932 | Temp: 0.0700
#   [Epoch 13] Batch 41/59 | Loss: 1.6320 | Temp: 0.0700
#   [Epoch 13] Batch 51/59 | Loss: 1.3548 | Temp: 0.0700
#   [Epoch 13] Batch 59/59 | Loss: 0.9223 | Temp: 0.0700
# >>> Epoch 13/20  Train: 1.3876  Val: 2.1586  LR: 2.73e-06
#
#   [Epoch 14] Batch 1/59 | Loss: 1.1994 | Temp: 0.0700
#   [Epoch 14] Batch 11/59 | Loss: 1.2636 | Temp: 0.0700
#   [Epoch 14] Batch 21/59 | Loss: 1.4367 | Temp: 0.0700
#   [Epoch 14] Batch 31/59 | Loss: 1.3375 | Temp: 0.0700
#   [Epoch 14] Batch 41/59 | Loss: 1.5688 | Temp: 0.0700
#   [Epoch 14] Batch 51/59 | Loss: 1.4608 | Temp: 0.0700
#   [Epoch 14] Batch 59/59 | Loss: 0.3931 | Temp: 0.0700
# >>> Epoch 14/20  Train: 1.3121  Val: 2.1636  LR: 2.06e-06
#
#   [Epoch 15] Batch 1/59 | Loss: 1.4353 | Temp: 0.0700
#   [Epoch 15] Batch 11/59 | Loss: 1.0369 | Temp: 0.0700
#   [Epoch 15] Batch 21/59 | Loss: 1.4102 | Temp: 0.0700
#   [Epoch 15] Batch 31/59 | Loss: 1.4601 | Temp: 0.0700
#   [Epoch 15] Batch 41/59 | Loss: 1.1236 | Temp: 0.0700
#   [Epoch 15] Batch 51/59 | Loss: 1.7109 | Temp: 0.0700
#   [Epoch 15] Batch 59/59 | Loss: 0.6988 | Temp: 0.0700
# >>> Epoch 15/20  Train: 1.3091  Val: 2.1665  LR: 1.46e-06
#
#   [Epoch 16] Batch 1/59 | Loss: 1.5789 | Temp: 0.0700
#   [Epoch 16] Batch 11/59 | Loss: 1.3388 | Temp: 0.0700
#   [Epoch 16] Batch 21/59 | Loss: 1.6658 | Temp: 0.0700
#   [Epoch 16] Batch 31/59 | Loss: 2.0821 | Temp: 0.0700
#   [Epoch 16] Batch 41/59 | Loss: 1.4768 | Temp: 0.0700
#   [Epoch 16] Batch 51/59 | Loss: 1.3008 | Temp: 0.0700
#   [Epoch 16] Batch 59/59 | Loss: 0.8337 | Temp: 0.0700
# >>> Epoch 16/20  Train: 1.3083  Val: 2.1718  LR: 9.55e-07
#
#   [Epoch 17] Batch 1/59 | Loss: 1.4347 | Temp: 0.0700
#   [Epoch 17] Batch 11/59 | Loss: 1.0437 | Temp: 0.0700
#   [Epoch 17] Batch 21/59 | Loss: 1.1802 | Temp: 0.0700
#   [Epoch 17] Batch 31/59 | Loss: 1.2891 | Temp: 0.0700
#   [Epoch 17] Batch 41/59 | Loss: 1.1978 | Temp: 0.0700
#   [Epoch 17] Batch 51/59 | Loss: 1.2336 | Temp: 0.0700
#   [Epoch 17] Batch 59/59 | Loss: 0.4059 | Temp: 0.0700
# >>> Epoch 17/20  Train: 1.2821  Val: 2.1627  LR: 5.45e-07
#
#   [Epoch 18] Batch 1/59 | Loss: 1.4775 | Temp: 0.0700
#   [Epoch 18] Batch 11/59 | Loss: 1.5126 | Temp: 0.0700
#   [Epoch 18] Batch 21/59 | Loss: 1.2987 | Temp: 0.0700
#   [Epoch 18] Batch 31/59 | Loss: 1.5142 | Temp: 0.0700
#   [Epoch 18] Batch 41/59 | Loss: 1.1447 | Temp: 0.0700
#   [Epoch 18] Batch 51/59 | Loss: 1.6355 | Temp: 0.0700
#   [Epoch 18] Batch 59/59 | Loss: 0.3673 | Temp: 0.0700
# >>> Epoch 18/20  Train: 1.2569  Val: 2.1671  LR: 2.45e-07
#
#   [Epoch 19] Batch 1/59 | Loss: 1.1310 | Temp: 0.0700
#   [Epoch 19] Batch 11/59 | Loss: 1.1393 | Temp: 0.0700
#   [Epoch 19] Batch 21/59 | Loss: 1.0954 | Temp: 0.0700
#   [Epoch 19] Batch 31/59 | Loss: 1.2998 | Temp: 0.0700
#   [Epoch 19] Batch 41/59 | Loss: 1.0564 | Temp: 0.0700
#   [Epoch 19] Batch 51/59 | Loss: 1.0800 | Temp: 0.0700
#   [Epoch 19] Batch 59/59 | Loss: 1.3885 | Temp: 0.0700
# >>> Epoch 19/20  Train: 1.2565  Val: 2.1771  LR: 6.16e-08
#
#   [Epoch 20] Batch 1/59 | Loss: 1.2280 | Temp: 0.0700
#   [Epoch 20] Batch 11/59 | Loss: 1.4198 | Temp: 0.0700
#   [Epoch 20] Batch 21/59 | Loss: 1.4217 | Temp: 0.0700
#   [Epoch 20] Batch 31/59 | Loss: 1.1406 | Temp: 0.0700
#   [Epoch 20] Batch 41/59 | Loss: 1.4237 | Temp: 0.0700
#   [Epoch 20] Batch 51/59 | Loss: 1.1272 | Temp: 0.0700
#   [Epoch 20] Batch 59/59 | Loss: 0.6969 | Temp: 0.0700
# >>> Epoch 20/20  Train: 1.2426  Val: 2.1785  LR: 0.00e+00
#
# Training complete. Best val loss: 2.0867

# %%
import matplotlib.pyplot as plt

# ── Step 9B — Training Loss Curves ────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(8, 4))
epochs = range(1, len(train_losses) + 1)
ax.plot(epochs, train_losses, marker="o", label="Train Loss")
ax.plot(epochs, val_losses,   marker="s", label="Val Loss")
ax.set_xlabel("Epoch")
ax.set_ylabel("InfoNCE Loss")
ax.set_title("EchoCare-CLIP Training Curve")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Final Train Loss : {train_losses[-1]:.4f}")
print(f"Final Val Loss   : {val_losses[-1]:.4f}")
print(f"Best  Val Loss   : {min(val_losses):.4f}  (epoch {val_losses.index(min(val_losses)) + 1})")
# Out:
# Final Train Loss : 1.2426
# Final Val Loss   : 2.1785
# Best  Val Loss   : 2.0867  (epoch 3)

# %% [markdown]
# ## Step 10 — Benchmarking
#
# Four complementary benchmarks are run on the held-out **test set**:
#
# ### A) Zero-Shot Retrieval (Recall@k)
# Given a query image, rank all test texts by cosine similarity and check whether the ground-truth paired text is within the top-k results — and vice versa (text→image). Reports R@1, R@5, R@10 in both directions.
#
# ### B) Zero-Shot Classification
# Build one **class prototype** text embedding per label (encoding the clinical description string). Assign each test image to the class whose prototype has the highest cosine similarity. Reports per-class and overall accuracy.
#
# ### C) Confusion Matrix
# Normalised heatmap of predicted vs. true labels from the zero-shot classification above.
#
# ### D) t-SNE Embedding Visualisation
# Reduce test image embeddings to 2-D with t-SNE and scatter-plot them coloured by true label. Good cluster separation indicates the image encoder has learned class-discriminative representations.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.manifold import TSNE

LABEL_COLORS = {"covid": "tab:red", "healthy": "tab:green", "other": "tab:blue"}


# ── A) Zero-shot retrieval ─────────────────────────────────────────────────────
@torch.no_grad()
def zero_shot_retrieval(
    model     : EchoCare_CLIP,
    dataloader: DataLoader,
    tokenizer : CLIPTokenizer,
    device    : torch.device,
    ks        : tuple = (1, 5, 10),
) -> tuple[dict, torch.Tensor]:
    """
    Image→Text and Text→Image retrieval Recall@k on the test set.

    For each query image, all N test texts are ranked by cosine similarity.
    R@k = fraction of queries where the ground-truth pair is in the top-k.

    Returns (metrics_dict, sim_matrix (N, N)).
    """
    model.eval()
    all_img_embs, all_txt_embs = [], []

    for images, texts, _ in dataloader:
        images = images.to(device)
        ids, mask = tokenize_texts(texts, tokenizer, device=device)
        all_img_embs.append(model.encode_image(images).cpu())
        all_txt_embs.append(model.encode_text(ids, mask).cpu())

    img_embs = torch.cat(all_img_embs)   # (N, D) L2-normalised
    txt_embs = torch.cat(all_txt_embs)   # (N, D) L2-normalised
    sim      = img_embs @ txt_embs.T     # (N, N) cosine similarity matrix
    N        = img_embs.size(0)
    labels   = torch.arange(N)

    metrics = {}
    for k in ks:
        k_eff   = min(k, N)
        # topk returns indices of k largest similarities along each row
        i2t_hits = (sim.topk(k_eff, dim=1).indices == labels.unsqueeze(1)).any(1)
        t2i_hits = (sim.T.topk(k_eff, dim=1).indices == labels.unsqueeze(1)).any(1)
        metrics[f"i2t_R@{k}"] = i2t_hits.float().mean().item()
        metrics[f"t2i_R@{k}"] = t2i_hits.float().mean().item()

    print(f"Zero-Shot Retrieval  (N={N} test samples)")
    print(f"{'':6s}  {'Image→Text':>12s}  {'Text→Image':>12s}")
    for k in ks:
        i2t = metrics[f"i2t_R@{k}"] * 100
        t2i = metrics[f"t2i_R@{k}"] * 100
        print(f"  R@{k:<4d}  {i2t:>11.1f}%  {t2i:>11.1f}%")

    return metrics, sim


# ── B & C) Zero-shot classification + confusion matrix ────────────────────────
@torch.no_grad()
def zero_shot_classification(
    model     : EchoCare_CLIP,
    dataloader: DataLoader,
    tokenizer : CLIPTokenizer,
    device    : torch.device,
) -> tuple[list, list]:
    """
    Classify each test image by finding the nearest class-prototype text embedding.

    Prototype texts = LABEL_TO_TEXT values (one per class).
    Predicted class = argmax cosine similarity between image embedding and prototypes.

    Returns (y_true, y_pred) as lists of label strings.
    """
    model.eval()

    # Build 3 class prototype embeddings  (3, D)
    prototype_texts = [LABEL_TO_TEXT[lbl] for lbl in LABEL_NAMES]
    ids, mask       = tokenize_texts(prototype_texts, tokenizer, device=device)
    prototypes      = model.encode_text(ids, mask)   # (3, D), L2-normalised

    y_true, y_pred = [], []

    for images, _, labels in dataloader:
        images   = images.to(device)
        img_embs = model.encode_image(images)          # (B, D)
        sims     = img_embs @ prototypes.T             # (B, 3)  — cosine similarity to each class
        pred_idx = sims.argmax(dim=1).cpu().tolist()
        y_true.extend(list(labels))
        y_pred.extend([LABEL_NAMES[i] for i in pred_idx])

    # Compute per-class and overall accuracy
    correct_per_class = {lbl: 0 for lbl in LABEL_NAMES}
    total_per_class   = {lbl: 0 for lbl in LABEL_NAMES}
    for t, p in zip(y_true, y_pred):
        total_per_class[t]   += 1
        correct_per_class[t] += int(t == p)

    overall = sum(correct_per_class.values()) / len(y_true)
    print(f"\nZero-Shot Classification  (Overall Accuracy: {overall*100:.1f}%)")
    for lbl in LABEL_NAMES:
        n   = total_per_class[lbl]
        acc = correct_per_class[lbl] / max(n, 1)
        print(f"  {lbl:8s}: {acc*100:5.1f}%  ({correct_per_class[lbl]}/{n})")

    return y_true, y_pred


def plot_confusion_matrix(y_true: list, y_pred: list):
    """Plot normalised (row-wise) confusion matrix."""
    cm_arr = confusion_matrix(y_true, y_pred, labels=LABEL_NAMES, normalize="true")
    fig, ax = plt.subplots(figsize=(5, 4))
    disp = ConfusionMatrixDisplay(cm_arr, display_labels=LABEL_NAMES)
    disp.plot(ax=ax, colorbar=False, cmap="Blues", values_format=".2f")
    ax.set_title("Confusion Matrix — Zero-Shot Classification (test set)")
    plt.tight_layout()
    plt.show()


# ── D) t-SNE embedding visualisation ──────────────────────────────────────────
@torch.no_grad()
def plot_tsne(
    model     : EchoCare_CLIP,
    dataloader: DataLoader,
    device    : torch.device,
):
    """t-SNE scatter of test image embeddings coloured by true label."""
    model.eval()
    all_embs, all_labels = [], []

    for images, _, labels in dataloader:
        embs = model.encode_image(images.to(device)).cpu().numpy()
        all_embs.append(embs)
        all_labels.extend(list(labels))

    all_embs = np.concatenate(all_embs, axis=0)  # (N, D)

    print(f"Running t-SNE on {len(all_labels)} test embeddings...")
    perp  = min(30, len(all_labels) - 1)
    embs2 = TSNE(n_components=2, perplexity=perp, random_state=42).fit_transform(all_embs)

    fig, ax = plt.subplots(figsize=(7, 6))
    for lbl in LABEL_NAMES:
        idx = [i for i, l in enumerate(all_labels) if l == lbl]
        ax.scatter(embs2[idx, 0], embs2[idx, 1],
                   c=LABEL_COLORS[lbl], label=lbl, alpha=0.7, s=18, edgecolors="none")
    ax.set_title("EchoCare-CLIP Test Set Embeddings (t-SNE)")
    ax.legend(title="Label")
    ax.axis("off")
    plt.tight_layout()
    plt.show()


# ── Load best checkpoint before evaluation ─────────────────────────────────────
try:
    model.load_state_dict(torch.load("echocare_clip_best.pth", map_location=device))
    print("Loaded best checkpoint for evaluation.\n")
except FileNotFoundError:
    print("[WARNING] echocare_clip_best.pth not found — evaluating current model weights.\n")

# ── Run all benchmarks ─────────────────────────────────────────────────────────
print("=" * 60)
print("A) Zero-Shot Retrieval")
print("=" * 60)
retrieval_metrics, sim_matrix = zero_shot_retrieval(model, test_loader, tokenizer, device)

print("\n" + "=" * 60)
print("B & C) Zero-Shot Classification + Confusion Matrix")
print("=" * 60)
y_true, y_pred = zero_shot_classification(model, test_loader, tokenizer, device)
plot_confusion_matrix(y_true, y_pred)

print("\n" + "=" * 60)
print("D) t-SNE Embedding Visualisation")
print("=" * 60)
plot_tsne(model, test_loader, device)
# Out:
# Loaded best checkpoint for evaluation.
#
# ============================================================
# A) Zero-Shot Retrieval
# ============================================================
# Zero-Shot Retrieval  (N=84 test samples)
#           Image→Text    Text→Image
#   R@1             2.4%          2.4%
#   R@5            14.3%         13.1%
#   R@10           27.4%         26.2%
#
# ============================================================
# B & C) Zero-Shot Classification + Confusion Matrix
# ============================================================
#
# Zero-Shot Classification  (Overall Accuracy: 81.0%)
#   covid   :  28.6%  (2/7)
#   healthy :  80.0%  (44/55)
#   other   : 100.0%  (22/22)
# ============================================================
# D) t-SNE Embedding Visualisation
# ============================================================
# Running t-SNE on 84 test embeddings...

# %% [markdown]
# ## Step 11 — End-to-End Shape Verification
#
# Final sanity check that traces tensor shapes through every stage of the pipeline. This cell should run to completion without errors even when the EchoCare weights file is absent.

# %%
print("=" * 55)
print("End-to-End Shape Verification")
print("=" * 55)

model.eval()
B = 2  # mini-batch size for this check

with torch.no_grad():

    # ── 1. Raw inputs ──────────────────────────────────────────────────────
    dummy_images = torch.rand(B, 3, 256, 256).to(device)
    dummy_texts  = [
        "Echo showing left ventricular dysfunction.",
        "Normal right heart with trivial pericardial effusion.",
    ]
    print(f"\n[1] Input images         : {tuple(dummy_images.shape)}")
    #     Expected: (2, 3, 256, 256)

    # ── 2. SwinTransformer multi-scale features ────────────────────────────
    raw_feats = model.image_encoder.encoder(dummy_images)
    print(f"[2] SwinTransformer stages:")
    stage_channels = [128, 256, 512, 1024, 2048]
    stage_spatials = [128,  64,  32,   16,    8]
    for i, f in enumerate(raw_feats):
        print(
            f"     Stage {i}: {tuple(f.shape)}"
            f"  (expected (B, {stage_channels[i]}, {stage_spatials[i]}, {stage_spatials[i]}))"
        )

    # ── 3. Global Average Pooling ──────────────────────────────────────────
    deep   = raw_feats[-1]                # (B, 2048, 8, 8)
    pooled = deep.mean(dim=(2, 3))        # (B, 2048)
    print(f"[3] After GAP (deepest)  : {tuple(pooled.shape)}")  # (2, 2048)

    # ── 4. Full image embedding ────────────────────────────────────────────
    image_emb = model.encode_image(dummy_images)  # (B, projection_dim)
    print(f"[4] Image embedding      : {tuple(image_emb.shape)}")  # (2, 256)
    print(f"    L2 norms (should be 1.0): {image_emb.norm(dim=-1).tolist()}")

    # ── 5. Text tokenisation ───────────────────────────────────────────────
    input_ids, attn_mask = tokenize_texts(dummy_texts, tokenizer, device=device)
    print(f"[5] Token ids            : {tuple(input_ids.shape)}")   # (2, 77)
    print(f"    Attention mask       : {tuple(attn_mask.shape)}")   # (2, 77)

    # ── 6. Full text embedding ─────────────────────────────────────────────
    text_emb = model.encode_text(input_ids, attn_mask)  # (B, projection_dim)
    print(f"[6] Text embedding       : {tuple(text_emb.shape)}")   # (2, 256)
    print(f"    L2 norms (should be 1.0): {text_emb.norm(dim=-1).tolist()}")

    # ── 7. Similarity matrix ───────────────────────────────────────────────
    sim = image_emb @ text_emb.T  # (B, B)
    print(f"[7] Similarity matrix    : {tuple(sim.shape)}")  # (2, 2)
    print(f"    Values:\n{sim}")

    # ── 8. InfoNCE loss ────────────────────────────────────────────────────
    loss, _, _ = model(dummy_images, input_ids, attn_mask)
    print(f"[8] InfoNCE loss         : {loss.item():.4f}")
    #     With random init & B=2, expect ≈ log(2) ≈ 0.693

    # ── 9. Learnable temperature ───────────────────────────────────────────
    temp = model.log_temperature.exp().item()
    print(f"[9] Temperature          : {temp:.4f}")

print("\n" + "=" * 55)
print("All shapes verified — pipeline is functional.")
print("=" * 55)
# Out:
# =======================================================
# End-to-End Shape Verification
# =======================================================
#
# [1] Input images         : (2, 3, 256, 256)
# [2] SwinTransformer stages:
#      Stage 0: (2, 128, 128, 128)  (expected (B, 128, 128, 128))
#      Stage 1: (2, 256, 64, 64)  (expected (B, 256, 64, 64))
#      Stage 2: (2, 512, 32, 32)  (expected (B, 512, 32, 32))
#      Stage 3: (2, 1024, 16, 16)  (expected (B, 1024, 16, 16))
#      Stage 4: (2, 2048, 8, 8)  (expected (B, 2048, 8, 8))
# [3] After GAP (deepest)  : (2, 2048)
# [4] Image embedding      : (2, 256)
#     L2 norms (should be 1.0): [1.0, 1.0]
# [5] Token ids            : (2, 77)
#     Attention mask       : (2, 77)
# [6] Text embedding       : (2, 256)
#     L2 norms (should be 1.0): [1.0, 1.0]
# [7] Similarity matrix    : (2, 2)
#     Values:
# tensor([[-0.0081, -0.1588],
#         [-0.0035, -0.1612]], device='cuda:0')
# [8] InfoNCE loss         : 0.9751
# [9] Temperature          : 0.0700
#
# =======================================================
# All shapes verified — pipeline is functional.
# =======================================================

# %% [markdown]
# ## Summary of Design Choices
#
# | Component | Choice | Rationale |
# |-----------|--------|-----------|
# | Image backbone | EchoCare SwinTransformer (`feature_size=128`, `depths=[2,2,18,2]`, 2D, SwinV2) | Pretrained on echocardiography; same config as released weights |
# | Image feature extraction | Deepest stage (2048 ch) + GAP | Deepest features are most semantically abstract; GAP gives a fixed-size vector |
# | Text backbone | Frozen CLIP `openai/clip-vit-base-patch32` text tower | Compact (~63M), purpose-built for image–text alignment; frozen to avoid forgetting |
# | Projection heads | 2-layer MLP (dim → dim → 256) | Standard in contrastive learning (MoCo v3, CLIP) |
# | Shared dim | `projection_dim=256` | Compact joint space that forces semantic compression |
# | Loss | Symmetric InfoNCE | Trains both image→text and text→image directions simultaneously |
# | Temperature | Learnable `log_temperature`, init `log(0.07)` | Adapts distribution sharpness; log-scale for numerical stability |
# | LR schedule | Cosine annealing | Smooth decay prevents abrupt LR drops; standard for transformers |
# | Label texts | Clinical descriptions per class | More informative than bare label names; gives CLIP text encoder meaningful context |
# | Normalisation | ImageNet mean/std | Standard starting point for SwinV2 initialised from vision pretraining |
#
# ## Benchmarks
#
# | Benchmark | Metric | Description |
# |-----------|--------|-------------|
# | Training curve | InfoNCE loss vs. epoch | Train & val loss — monitors overfitting |
# | Zero-shot retrieval | R@1, R@5, R@10 | Image↔text matching without any supervised head |
# | Zero-shot classification | Per-class & overall accuracy | Nearest class-prototype assignment |
# | Confusion matrix | Normalised per-row heatmap | Shows which classes are confused |
# | t-SNE | 2-D embedding scatter | Visual cluster quality of learned representations |
#
# ## Connecting different data
# `LungUltrasoundDataset` expects PNGs in `root_dir/{split}/{label}/*.png`.
# Update `config["dataset_root"]` to point to your Google Drive folder.
#
# ## Next steps
# 1. Unfreeze the CLIP text encoder after initial convergence for domain adaptation.
# 2. Add a cosine warmup LR schedule for the first few epochs.
# 3. Increase batch size (≥64) — more negatives per InfoNCE step improves representation quality.
# 4. Add a **linear probe** evaluation as a supervised upper bound.
# 5. Consider domain-adapted text encoders (e.g., BioViL-T, CheXzero) for better medical text alignment.
